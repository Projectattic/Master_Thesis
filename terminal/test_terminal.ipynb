# %%
######### TEST OF INIT Terminal with various fullness

import containerClass
import stackClass
import rowClass
import terminalClass

# full_container_list = [containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))]
# half_container_list = [containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))]
# single_container_list = [containerClass.Container("ISO_10",float(10))]

# # full_stack_list = [Stack("A","1")]
# # empty_row = rowClass.Row("A",[],5,6)
# # print(empty_row)
# half_full_stacks = [stackClass.Stack("A","1",full_container_list,6),stackClass.Stack("A","2",half_container_list,6),stackClass.Stack("A","3",single_container_list,6)]
# half_full_row = rowClass.Row("A",half_full_stacks,5,6)


test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))],6),
stackClass.Stack("A","2",[containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))],6),
stackClass.Stack("A","3",[containerClass.Container("ISO_10",float(10))],6)],5,6)
#print(test_row)
test_rowB = rowClass.Row("B",[stackClass.Stack("B","1",[containerClass.Container("ISO_11",float(1)),containerClass.Container("ISO_12",float(2)),containerClass.Container("ISO_13",float(3)),containerClass.Container("ISO_14",float(4)),containerClass.Container("ISO_15",float(5)),containerClass.Container("ISO_16",float(6))],6),
stackClass.Stack("B","2",[containerClass.Container("ISO_17",float(7)),containerClass.Container("ISO_18",float(8)),containerClass.Container("ISO_19",float(9))],6),
stackClass.Stack("B","3",[containerClass.Container("ISO_20",float(10))],6)],5,6)

test_rowC = rowClass.Row("C",[stackClass.Stack("C","1",[containerClass.Container("ISO_21",float(1)),containerClass.Container("ISO_22",float(2)),containerClass.Container("ISO_23",float(3)),containerClass.Container("ISO_24",float(4)),containerClass.Container("ISO_25",float(5)),containerClass.Container("ISO_26",float(6))],6),
stackClass.Stack("C","2",[containerClass.Container("ISO_27",float(7)),containerClass.Container("ISO_28",float(8)),containerClass.Container("ISO_29",float(9))],6),
stackClass.Stack("C","3",[containerClass.Container("ISO_30",float(10))],6)],5,6)

test_rowD = rowClass.Row("D",[],5,6)

test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)


#empty terminal

empty_test_terminal = terminalClass.Terminal([],5,5,6)
print(empty_test_terminal.pretty_str())
print(test_terminal.pretty_str())

# %%
######### TEST OF INIT Terminal with various fullness

import containerClass
import stackClass
import rowClass
import terminalClass

# full_container_list = [containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))]
# half_container_list = [containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))]
# single_container_list = [containerClass.Container("ISO_10",float(10))]

# # full_stack_list = [Stack("A","1")]
# # empty_row = rowClass.Row("A",[],5,6)
# # print(empty_row)
# half_full_stacks = [stackClass.Stack("A","1",full_container_list,6),stackClass.Stack("A","2",half_container_list,6),stackClass.Stack("A","3",single_container_list,6)]
# half_full_row = rowClass.Row("A",half_full_stacks,5,6)


test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))],6),
stackClass.Stack("A","2",[containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))],6),
stackClass.Stack("A","3",[containerClass.Container("ISO_10",float(10))],6)],5,6)
#print(test_row)
test_rowB = rowClass.Row("B",[stackClass.Stack("B","1",[containerClass.Container("ISO_11",float(1)),containerClass.Container("ISO_12",float(2)),containerClass.Container("ISO_13",float(3)),containerClass.Container("ISO_14",float(4)),containerClass.Container("ISO_15",float(5)),containerClass.Container("ISO_16",float(6))],6),
stackClass.Stack("B","2",[containerClass.Container("ISO_17",float(7)),containerClass.Container("ISO_18",float(8)),containerClass.Container("ISO_19",float(9))],6),
stackClass.Stack("B","3",[containerClass.Container("ISO_20",float(10))],6)],5,6)

test_rowC = rowClass.Row("C",[stackClass.Stack("C","1",[containerClass.Container("ISO_21",float(1)),containerClass.Container("ISO_22",float(2)),containerClass.Container("ISO_23",float(3)),containerClass.Container("ISO_24",float(4)),containerClass.Container("ISO_25",float(5)),containerClass.Container("ISO_26",float(6))],6),
stackClass.Stack("C","2",[containerClass.Container("ISO_27",float(7)),containerClass.Container("ISO_28",float(8)),containerClass.Container("ISO_29",float(9))],6),
stackClass.Stack("C","3",[containerClass.Container("ISO_30",float(10))],6)],5,6)

test_rowD = rowClass.Row("D",[],5,6)

test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)

#
test_terminal.add_container(containerClass.Container("ISO_nu",float(21)),"C3")
print(test_terminal.pretty_str())

while not (test_terminal.rows["A"].stacks["1"].is_empty()):
    cont = test_terminal.remove_container_from_row("A1")
    print(cont)
    print(test_terminal.pretty_str())


# print(test_row)

# %%
########## Removing containers by container number #######
import containerClass
import stackClass
import rowClass
import terminalClass

# full_container_list = [containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))]
# half_container_list = [containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))]
# single_container_list = [containerClass.Container("ISO_10",float(10))]

# # full_stack_list = [Stack("A","1")]
# # empty_row = rowClass.Row("A",[],5,6)
# # print(empty_row)
# half_full_stacks = [stackClass.Stack("A","1",full_container_list,6),stackClass.Stack("A","2",half_container_list,6),stackClass.Stack("A","3",single_container_list,6)]
# half_full_row = rowClass.Row("A",half_full_stacks,5,6)


test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))],6),
stackClass.Stack("A","2",[containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))],6),
stackClass.Stack("A","3",[containerClass.Container("ISO_10",float(10))],6)],5,6)
#print(test_row)
test_rowB = rowClass.Row("B",[stackClass.Stack("B","1",[containerClass.Container("ISO_11",float(1)),containerClass.Container("ISO_12",float(2)),containerClass.Container("ISO_13",float(3)),containerClass.Container("ISO_14",float(4)),containerClass.Container("ISO_15",float(5)),containerClass.Container("ISO_16",float(6))],6),
stackClass.Stack("B","2",[containerClass.Container("ISO_17",float(7)),containerClass.Container("ISO_18",float(8)),containerClass.Container("ISO_19",float(9))],6),
stackClass.Stack("B","3",[containerClass.Container("ISO_20",float(10))],6)],5,6)

test_rowC = rowClass.Row("C",[stackClass.Stack("C","1",[containerClass.Container("ISO_21",float(1)),containerClass.Container("ISO_22",float(2)),containerClass.Container("ISO_23",float(3)),containerClass.Container("ISO_24",float(4)),containerClass.Container("ISO_25",float(5)),containerClass.Container("ISO_26",float(6))],6),
stackClass.Stack("C","2",[containerClass.Container("ISO_27",float(7)),containerClass.Container("ISO_28",float(8)),containerClass.Container("ISO_29",float(9))],6),
stackClass.Stack("C","3",[containerClass.Container("ISO_30",float(10))],6)],5,6)

test_rowD = rowClass.Row("D",[],5,6)

test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)


print(test_terminal.pretty_str())
removed_container = test_terminal.remove_container_from_depth("ISO_1")
print(removed_container)
print(test_terminal.pretty_str())

# %%
######### TEST OF INIT Terminal with various fullness

import containerClass
import stackClass
import rowClass
import terminalClass

# full_container_list = [containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))]
# half_container_list = [containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))]
# single_container_list = [containerClass.Container("ISO_10",float(10))]

# # full_stack_list = [Stack("A","1")]
# # empty_row = rowClass.Row("A",[],5,6)
# # print(empty_row)
# half_full_stacks = [stackClass.Stack("A","1",full_container_list,6),stackClass.Stack("A","2",half_container_list,6),stackClass.Stack("A","3",single_container_list,6)]
# half_full_row = rowClass.Row("A",half_full_stacks,5,6)


test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))],6),
stackClass.Stack("A","2",[containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))],6),
stackClass.Stack("A","3",[containerClass.Container("ISO_10",float(10))],6)],5,6)
#print(test_row)
test_rowB = rowClass.Row("B",[stackClass.Stack("B","1",[containerClass.Container("ISO_11",float(1)),containerClass.Container("ISO_12",float(2)),containerClass.Container("ISO_13",float(3)),containerClass.Container("ISO_14",float(4)),containerClass.Container("ISO_15",float(5)),containerClass.Container("ISO_16",float(6))],6),
stackClass.Stack("B","2",[containerClass.Container("ISO_17",float(7)),containerClass.Container("ISO_18",float(8)),containerClass.Container("ISO_19",float(9))],6),
stackClass.Stack("B","3",[containerClass.Container("ISO_20",float(10))],6)],5,6)

test_rowC = rowClass.Row("C",[stackClass.Stack("C","1",[containerClass.Container("ISO_21",float(1)),containerClass.Container("ISO_22",float(2)),containerClass.Container("ISO_23",float(3)),containerClass.Container("ISO_24",float(4)),containerClass.Container("ISO_25",float(5)),containerClass.Container("ISO_26",float(6))],6),
stackClass.Stack("C","2",[containerClass.Container("ISO_27",float(7)),containerClass.Container("ISO_28",float(8)),containerClass.Container("ISO_29",float(9))],6),
stackClass.Stack("C","3",[containerClass.Container("ISO_30",float(10))],6)],5,6)

test_rowD = rowClass.Row("D",[],5,6)

test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)


#empty terminal

print(test_terminal.free_spots)

# %%
########## Removing containers by container number #######
import containerClass
import stackClass
import rowClass
import terminalClass

# full_container_list = [containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))]
# half_container_list = [containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))]
# single_container_list = [containerClass.Container("ISO_10",float(10))]

# # full_stack_list = [Stack("A","1")]
# # empty_row = rowClass.Row("A",[],5,6)
# # print(empty_row)
# half_full_stacks = [stackClass.Stack("A","1",full_container_list,6),stackClass.Stack("A","2",half_container_list,6),stackClass.Stack("A","3",single_container_list,6)]
# half_full_row = rowClass.Row("A",half_full_stacks,5,6)


test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2)),containerClass.Container("ISO_3",float(3)),containerClass.Container("ISO_4",float(4)),containerClass.Container("ISO_5",float(5)),containerClass.Container("ISO_6",float(6))],6),
stackClass.Stack("A","2",[containerClass.Container("ISO_7",float(7)),containerClass.Container("ISO_8",float(8)),containerClass.Container("ISO_9",float(9))],6),
stackClass.Stack("A","3",[containerClass.Container("ISO_10",float(10))],6)],5,6)
#print(test_row)
test_rowB = rowClass.Row("B",[stackClass.Stack("B","1",[containerClass.Container("ISO_11",float(1)),containerClass.Container("ISO_12",float(2)),containerClass.Container("ISO_13",float(3)),containerClass.Container("ISO_14",float(4)),containerClass.Container("ISO_15",float(5)),containerClass.Container("ISO_16",float(6))],6),
stackClass.Stack("B","2",[containerClass.Container("ISO_17",float(7)),containerClass.Container("ISO_18",float(8)),containerClass.Container("ISO_19",float(9))],6),
stackClass.Stack("B","3",[containerClass.Container("ISO_20",float(10))],6)],5,6)

test_rowC = rowClass.Row("C",[stackClass.Stack("C","1",[containerClass.Container("ISO_21",float(1)),containerClass.Container("ISO_22",float(2)),containerClass.Container("ISO_23",float(3)),containerClass.Container("ISO_24",float(4)),containerClass.Container("ISO_25",float(5)),containerClass.Container("ISO_26",float(6))],6),
stackClass.Stack("C","2",[containerClass.Container("ISO_27",float(7)),containerClass.Container("ISO_28",float(8)),containerClass.Container("ISO_29",float(9))],6),
stackClass.Stack("C","3",[containerClass.Container("ISO_30",float(10))],6)],5,6)

test_rowD = rowClass.Row("D",[],5,6)

test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)

print(test_terminal.to_prolog_string())

# %%
import containerClass
import stackClass
import rowClass
import terminalClass
test_rowA = rowClass.Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2))],6)],5,6)
# test_rowA = rowClass.Row("A",[],5,6)
test_rowB = rowClass.Row("B",[],5,6)
test_rowC = rowClass.Row("C",[],5,6)
test_rowD = rowClass.Row("D",[],5,6)
test_rowE = rowClass.Row("E",[],5,6)

test_terminal = terminalClass.Terminal([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)


#empty terminal

print(test_terminal.free_spots)

# %%
from containerClass import Container
from stackClass import Stack
from rowClass import Row
from blockClass import Block
from terminalClass import Terminal
import pprint
# test_rowA = Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2))],6)],5,6)
# # test_rowA = rowClass.Row("A",[],5,6)
# test_rowB = Row("B",[],5,6)
# test_rowC = Row("C",[],5,6)
# test_rowD = Row("D",[],5,6)
# test_rowE = Row("E",[],5,6)

# test_block = Block([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)

# print(test_terminal.free_spots)
test_container = Container("ISO_1",23)
test_container.synthetic_dwell_time = 33
test_container2 = Container("ISO_2",22)
test_container2.synthetic_dwell_time = 1
test_container3 = Container("ISO_3",22)
test_container3.synthetic_dwell_time = 112
empty_terminal = Terminal([],2,2,2,3)
empty_terminal.add_container(test_container,"AB0")
empty_terminal.add_container(test_container2,"AB0")
empty_terminal.add_container(test_container3,"AB0")
print(empty_terminal.pretty_str())
# print(f"block_utils: {empty_terminal.get_block_utilizations()}")
# print(f"empty_stacks: {empty_terminal.get_empty_stacks()}")
# print(f"highest_stacks_available: {empty_terminal.get_highest_stacks()}")
# print(f"lowest_stacks: {empty_terminal.get_lowest_stacks()}")
# print(f"available_stacks: {empty_terminal.get_available_stacks()}")
# print(f"dwell_times: {empty_terminal.get_top_spot_container_stacks()}")
cont_returned, reshuffle_list = empty_terminal.remove_container("ISO_2",True)
print(f"cont_returned: {cont_returned}")
print(f"reshuffle_list: {reshuffle_list}")
print(empty_terminal.pretty_str())
print(f"block_utils: {empty_terminal.get_block_utilizations()}")
print(f"empty_stacks: {empty_terminal.get_empty_stacks()}")
print(f"highest_stacks_available: {empty_terminal.get_highest_stacks()}")
print(f"lowest_stacks: {empty_terminal.get_lowest_stacks()}")
print(f"available_stacks: {empty_terminal.get_available_stacks()}")
print(f"dwell_times: {empty_terminal.get_top_spot_container_stacks()}")
# Out:
# {
#     "A": {
#         "AA": {
#             "AA0": [
#                 "None",
#                 "None",
#                 "None"
#             ],
#             "AA1": [
#                 "None",
#                 "None",
#                 "None"
#             ]
#         },
#         "AB": {
#             "AB0": [
#                 "ISO_3",
#                 "ISO_2",
#                 "ISO_1"
#             ],
#             "AB1": [
#                 "None",
#                 "None",
#                 "None"
#             ]
#         }
#     },
#     "B": {
#         "BA": {
#             "BA0": [
#                 "None",
#                 "None",
#                 "None"
#             ],
#             "BA1": [
#                 "None",
#                 "None",
#                 "None"
#             ]
#         },
#         "BB": {
#             "BB0": [
#                 "None",
#                 "None",
#                 "None"
#             ],
#             "BB1": [
# ...

# %%
from containerClass import Container
from stackClass import Stack
from rowClass import Row
from blockClass import Block
from terminalClass import Terminal
import pprint
test_rowA = Row("A",[stackClass.Stack("A","1",[containerClass.Container("ISO_1",float(1)),containerClass.Container("ISO_2",float(2))],6)],5,6)
# test_rowA = rowClass.Row("A",[],5,6)
test_rowB = Row("B",[],5,6)
test_rowC = Row("C",[],5,6)
test_rowD = Row("D",[],5,6)
test_rowE = Row("E",[],5,6)

test_block = Block([test_rowA,test_rowB,test_rowC,test_rowD,test_rowE],5,5,6)

print(test_terminal.free_spots)
test_container = Container("ISO_1",23)
test_container.synthetic_dwell_time = 33
empty_terminal = Terminal([],2,2,2,2)
empty_terminal.add_container(test_container,"AB0")
print(empty_terminal.pretty_str())
print(f"block_utils: {empty_terminal.get_block_utilizations()}")
print(f"empty_stacks: {empty_terminal.get_empty_stacks()}")
print(f"highest_stacks_available: {empty_terminal.get_highest_stacks()}")
print(f"lowest_stacks: {empty_terminal.get_lowest_stacks()}")
print(f"available_stacks: {empty_terminal.get_available_stacks()}")
print(f"dwell_times: {empty_terminal.get_top_spot_container_stacks()}")
